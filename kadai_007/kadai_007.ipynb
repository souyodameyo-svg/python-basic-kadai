# %%
# 1. リスト「array」の作成
array = [
    "月曜日は晴れです",        # index: 0
    "火曜日は雨です",          # index: 1
    "水曜日は晴れです",        # index: 2
    "木曜日は晴れです",        # index: 3
    "金曜日は曇りです",        # index: 4
    "土曜日は曇りのち雨です",  # index: 5
    "日曜日は雷雨です"         # index: 6
]

# %%
# 2. データの取り出し（２番目　水曜日）
print(array[2])  # 出力
# Out:
# 水曜日は晴れです
